# %%
import matplotlib.pyplot as plt

# %%
print("=====SOAL1====")
s2_a = 0
s2_b = 1
s2_c = 4
s2_d = 7
s2_e = 5
s2_f = 0
hasil_a = s2_a + s2_b + s2_c + s2_d + s2_e + s2_f
print("hasil dari tamat S2 adalah : " + str(hasil_a))

s1_a = 4
s1_b = 12
s1_c = 6
s1_d = 13
s1_e = 14
s1_f = 0
hasil_b = s1_a + s1_b + s1_c + s1_d + s1_e + s1_f
print("hasil dari tamat S1 adalah : " + str(hasil_b))

sma_a = 12
sma_b = 17
sma_c = 5
sma_d = 20
sma_e = 11
sma_f = 75
hasil_c = sma_a + sma_b + sma_c + sma_d + sma_e + sma_f
print("hasil dari tamat SMA adalah : " + str(hasil_c))

smp_a = 5
smp_b = 6
smp_c = 15
smp_d = 9
smp_e = 20
smp_f = 15
hasil_d = smp_a + smp_b + smp_c + smp_d + smp_e + smp_f
print("hasil dari tamat SMP adalah : " + str(hasil_d))

sd_a = 1
sd_b = 8
sd_c = 0
sd_d = 19
sd_e = 10
sd_f = 0
hasil_e = sd_a + sd_b + sd_c + sd_d + sd_e + sd_f
print("hasil dari SD adalah : " + str(hasil_e))

td_a = 2
td_b = 14
td_c = 3
td_d = 10
td_e = 0
td_f = 1
hasil_f = td_a + td_b + td_c + td_d + td_e + td_f
print("hasil dari Tidak Diketahui adalah : " + str(hasil_f))
print()

print("====SOAL2====")
hasil1 = hasil_a * 0.25
hasil2 = hasil_b * 0.20
hasil3 = hasil_c * 0.15
hasil4 = hasil_d * 0.10
hasil5 = hasil_e * 0.5
hasil6 = hasil_f * 0.3
print("hasil dari tamat S2 adalah : " + str(hasil1))
print("hasil dari tamat S1 adalah : " + str(hasil2))
print("hasil dari tamat SMA adalah : " + str(hasil3))
print("hasil dari tamat SMP adalah : " + str(hasil4))
print("hasil dari SD adalah : " + str(hasil5))
print("hasil dari Tidak Diketahui adalah : " + str(hasil6))
print()

print("====SOAL3====")
a_index = 0.25
b_index = 0.20
c_index = 0.15
d_index = 0.10
e_index = 0.5
f_index = 0.3
s2_1 = 0 * a_index
s1_1 = 4 * b_index
sma_1 = 12 * c_index
smp_1 = 5 * d_index
sd_1 = 1 * e_index
td_1 = 2 * f_index

s2_2 = 1 * a_index
s1_2 = 12 * b_index
sma_2 = 7 * c_index
smp_2 = 6 * d_index
sd_2 = 8 * e_index
td_2 = 14 * f_index

s2_3 = 4 * a_index
s1_3 = 6 * b_index
sma_3 = 5 * c_index
smp_3 = 15 * d_index
sd_3 = 0 * e_index
td_3 = 3 * f_index

s2_4 = 7 * a_index
s1_4 = 13 * b_index
sma_4 = 20 * c_index
smp_4 = 9 * d_index
sd_4 = 19 * e_index
td_4 = 10 * f_index

s2_5 = 5 * a_index
s1_5 = 14 * b_index
sma_5 = 11 * c_index
smp_5 = 20 * d_index
sd_5 = 10 * e_index
td_5 = 0 * f_index

s2_6 = 0 * a_index
s1_6 = 0 * b_index
sma_6 = 75 * c_index
smp_6 = 15 * d_index
sd_6 = 1 * e_index
td_6 = 1 * f_index
print("usia 70")
print("maka hasil dari bobt : " + str(s2_1))
print("maka hasil dari bobt : " + str(s1_1))
print("maka hasil dari bobt : " + str(sma_1))
print("maka hasil dari bobt : " + str(smp_1))
print("maka hasil dari bobt : " + str(sd_1))
print("maka hasil dari bobt : " + str(td_1))

print("usia 60")
print("maka hasil dari bobt : " + str(s2_2))
print("maka hasil dari bobt : " + str(s1_2))
print("maka hasil dari bobt : " + str(sma_2))
print("maka hasil dari bobt : " + str(smp_2))
print("maka hasil dari bobt : " + str(sd_2))
print("maka hasil dari bobt : " + str(td_2))

print("usia 50")
print("maka hasil dari bobt : " + str(s2_3))
print("maka hasil dari bobt : " + str(s1_3))
print("maka hasil dari bobt : " + str(sma_3))
print("maka hasil dari bobt : " + str(smp_3))
print("maka hasil dari bobt : " + str(sd_3))
print("maka hasil dari bobt : " + str(td_3))

print("usia 40")
print("maka hasil dari bobt : " + str(s2_4))
print("maka hasil dari bobt : " + str(s1_4))
print("maka hasil dari bobt : " + str(sma_4))
print("maka hasil dari bobt : " + str(smp_4))
print("maka hasil dari bobt : " + str(sd_4))
print("maka hasil dari bobt : " + str(td_4))

print("usia 30")
print("maka hasil dari bobt : " + str(s2_5))
print("maka hasil dari bobt : " + str(s1_5))
print("maka hasil dari bobt : " + str(sma_5))
print("maka hasil dari bobt : " + str(smp_5))
print("maka hasil dari bobt : " + str(sd_5))
print("maka hasil dari bobt : " + str(td_5))

print("usia 20")
print("maka hasil dari bobt : " + str(s2_6))
print("maka hasil dari bobt : " + str(s1_6))
print("maka hasil dari bobt : " + str(sma_6))
print("maka hasil dari bobt : " + str(smp_6))
print("maka hasil dari bobt : " + str(sd_6))
print("maka hasil dari bobt : " + str(td_6))
print()

print("====SOAL4====")
terkecil = {"usia 70"}
print("maka bobot terkecil adalah : " + str(terkecil))
print()

print("====SOAL5====")
#grafik BAR
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ['s2', 's1', 'sma', 'smp', 'sd', 'td']
siswa = [17, 49, 140, 70, 38, 30 ]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black']
plt.title("Pendidikan")
plt.bar(jurusan, siswa, color = c)
plt.show()
print()

#pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['s2', 's1', 'sma', 'smp', 'sd', 'td']
siswa = [17, 49, 140, 70, 38, 30 ]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black']
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
print()

#grafik BAR
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
jurusan = ['u70', 'u60', 'u50', 'u40', 'u30', 'td']
siswa = [24, 58, 33, 78, 60, 92 ]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black']
plt.title("Pendidikan")
plt.bar(jurusan, siswa, color = c)
plt.show()
print()

#pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
jurusan = ['u70', 'u60', 'u50', 'u40', 'u30', 'td']
siswa = [24, 58, 33, 78, 60, 92 ]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black']
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
# Out:
# =====SOAL1====
# hasil dari tamat S2 adalah : 17
# hasil dari tamat S1 adalah : 49
# hasil dari tamat SMA adalah : 140
# hasil dari tamat SMP adalah : 70
# hasil dari SD adalah : 38
# hasil dari Tidak Diketahui adalah : 30
#
# ====SOAL2====
# hasil dari tamat S2 adalah : 4.25
# hasil dari tamat S1 adalah : 9.8
# hasil dari tamat SMA adalah : 21.0
# hasil dari tamat SMP adalah : 7.0
# hasil dari SD adalah : 19.0
# hasil dari Tidak Diketahui adalah : 9.0
#
# ====SOAL3====
# usia 70
# maka hasil dari bobt : 0.0
# maka hasil dari bobt : 0.8
# maka hasil dari bobt : 1.7999999999999998
# maka hasil dari bobt : 0.5
# maka hasil dari bobt : 0.5
# maka hasil dari bobt : 0.6
# usia 60
# maka hasil dari bobt : 0.25
# maka hasil dari bobt : 2.4000000000000004
# maka hasil dari bobt : 1.05
# maka hasil dari bobt : 0.6000000000000001
# maka hasil dari bobt : 4.0
# maka hasil dari bobt : 4.2
# usia 50
# maka hasil dari bobt : 1.0
# maka hasil dari bobt : 1.2000000000000002
# ...
