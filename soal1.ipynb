# %%
beras = 11400 #perkilo
minyak = 12700 #perliter
ayam = 3400 #pergram
telur = 21800 #per 1kg
popok = 27000 #per pcs
sabun_cuci = 1800 #per 100gr
buah_anggur = 3800 #per 100gr
roti_tawar = 8500 #per 100gr
tissu = 6400 #per pcs
mie_instan = 2200 #per pcs

print("===Belanjaan Tia===")
beras_tia = 4
ayam_tia = 2
telur_tia = 3
sabun_cuci_tia = 5
buah_anggur_tia = 4
roti_tawar_tia = 2
mie_instan_tia = 12
jb_tia = (beras_tia * beras) + (ayam_tia * (ayam * 10)) + (telur_tia * telur) + (sabun_cuci_tia * sabun_cuci) + (buah_anggur_tia * buah_anggur) + (roti_tawar_tia * roti_tawar) + (mie_instan_tia * mie_instan)
diskon = 85 #kebalikan dari 15
jb_diskon_tia = (jb_tia / 100) * diskon
print("Maka jumlah belanjaan tia Rp" + str(jb_tia))
print("Maka jumlah belanjaan tia setelah mendapatkan diskon adalah Rp" + str(jb_diskon_tia))
print("")
print("")

print("===Belanjaan Hana===")
minyak_hana = 2
ayam_hana = 5
telur_hana = 1.5
sabun_cuci_hana = 3
buah_anggur_hana = 8
roti_tawar_hana = 3
tissu_hana = 2
mie_instan_hana = 20
jb_hana = (minyak_hana * minyak) + (ayam_hana * ayam) + (telur_hana * telur) + (sabun_cuci_hana * sabun_cuci) + (buah_anggur_hana * buah_anggur) + (roti_tawar_hana * roti_tawar) + (tissu_hana * tissu) + (mie_instan_hana * mie_instan)
diskon = 90 #kebalikan dari 10
jb_diskon_hana = (jb_hana / 100) * diskon
print("Maka jumlah belanjaan hana Rp" + str(jb_hana))
print("Maka jumlah belanjaan hana setelah mendapatkan diskon adalah Rp" + str(jb_diskon_hana))
print("")
print("")

print("===Belanjaan Widia===")
beras_widia = 1
minyak_widia = 1
telur_widia = 1
buah_anggur_widia = 5
tissu_widia = 3
mie_instan_widia = 16
jb_widia =(beras_widia * beras) + (minyak_widia * minyak) + (telur_widia * telur) + (buah_anggur_widia * buah_anggur) + (tissu_widia * tissu) + (mie_instan_widia * mie_instan)
print("Maka  jumlah belanjaan widia Rp" + str(jb_widia))
print("")
print("")

print("===Belanjaan Romi===")
minyak_romi = 3
telur_romi = 2
popok_romi = 4
sabun_cuci_romi = 8
mie_instan_romi = 8
jb_romi = (minyak_romi * minyak) + (telur_romi * telur) + (popok_romi * popok) + (sabun_cuci_romi * sabun_cuci) + (mie_instan_romi * mie_instan)
diskon = 85 #kebalikan dari 15
jb_diskon_romi = (jb_romi / 100) * diskon
print("Maka jumlah belanjaan Romi Rp" + str(jb_romi))
print("Maka jumlah belanjaan romi setelah mendapatkan diskon adalah Rp" + str(jb_diskon_romi))
print("")
print("")

print("===Belanjaan Samsul===")
ayam_samsul = 3
telur_samsul = 4
popok_samsul = 2
buah_anggur_samsul = 7
tissu_samsul = 5
mie_instan_samsul = 10
jb_samsul = (ayam_samsul * (ayam * 10)) + (telur_samsul * telur) + (popok_samsul * popok) + (buah_anggur_samsul * buah_anggur) + (tissu_samsul * tissu) + (mie_instan_samsul * mie_instan)
diskon = 75 #kebalikan dari 25
jb_diskon_samsul = (jb_samsul / 100) * diskon
print("Maka jumlah belanjaan Samsul Rp" + str(jb_samsul))
print("Maka jumlah belanjaan samsul setelah mendapatkan diskon adalah Rp" + str(jb_diskon_samsul))
print("")
print("")

print("===Belanjaan Dimas===")
ayam_dimas = 5
popok_dimas = 5
sabun_cuci_dimas = 4
buah_anggur_dimas = 3
roti_tawar_dimas = 5
mie_instan_dimas = 6
jb_dimas = (ayam_dimas * (ayam *10)) + (popok_dimas * popok) + (sabun_cuci_dimas * sabun_cuci) + (buah_anggur_dimas * buah_anggur) + (roti_tawar_dimas * roti_tawar) + (mie_instan_dimas * mie_instan)
diskon = 75 #kebalikan dari 25
jb_diskon_dimas = (jb_dimas / 100) * diskon
print("Maka jumlah belanjaan Dimas Rp" + str(jb_dimas))
print("Maka jumlah belanjaan Dimas setelah mendapatkan diskon adalah Rp" + str(jb_diskon_dimas))
print("")
print("")

print("===Yang Mendapatkan Diskon 10%===")
nama = ["Hana"]
print(nama[0])

print("")
print("===Yang Mendapatkan Diskon 15%===")
nama = ["Tia", "Romi"]
print(nama[0])
print(nama[1])

print("")
print("===Yang Mendapatkan Diskon 25%===")
nama = ["Samsul", "Dimas"]
print(nama[0])
print(nama[1])

print("")
print("===Belanja Yang Paling Besar Adalah===")
nama = ["Dimas"]
print(nama[0])
print() 

print("==SOAL 3==")

max = [284475]
print("maka jumlah belanjaan paling besar setelah diskon adalah dimas Rp. " + str(max)) 

print("==SOAL 4==")

tenpersen = {"Hana" : "Rp. 173880"}
print("maka yang mendapatkan diskon 10 persen adalah : " + str(tenpersen))
# Out:
# ===Belanjaan Tia===
# Maka jumlah belanjaan tia Rp246600
# Maka jumlah belanjaan tia setelah mendapatkan diskon adalah Rp209610.0
#
#
# ===Belanjaan Hana===
# Maka jumlah belanjaan hana Rp193200.0
# Maka jumlah belanjaan hana setelah mendapatkan diskon adalah Rp173880.0
#
#
# ===Belanjaan Widia===
# Maka  jumlah belanjaan widia Rp119300
#
#
# ===Belanjaan Romi===
# Maka jumlah belanjaan Romi Rp221700
# Maka jumlah belanjaan romi setelah mendapatkan diskon adalah Rp188445.0
#
#
# ===Belanjaan Samsul===
# Maka jumlah belanjaan Samsul Rp323800
# Maka jumlah belanjaan samsul setelah mendapatkan diskon adalah Rp242850.0
#
#
# ===Belanjaan Dimas===
# Maka jumlah belanjaan Dimas Rp379300
# Maka jumlah belanjaan Dimas setelah mendapatkan diskon adalah Rp284475.0
#
#
# ===Yang Mendapatkan Diskon 10%===
# Hana
#
# ===Yang Mendapatkan Diskon 15%===
# Tia
# Romi
#
# ===Yang Mendapatkan Diskon 25%===
# Samsul
# Dimas
#
# ===Belanja Yang Paling Besar Adalah===
# Dimas
#
# ==SOAL 3==
# maka jumlah belanjaan paling besar setelah diskon adalah dimas Rp. [284475]
# ==SOAL 4==
# maka yang mendapatkan diskon 10 persen adalah : {'Hana': 'Rp. 173880'}
