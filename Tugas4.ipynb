# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
burger = 24000
pizza = 52000
dimsum = 30000
ekado = 7500
milkshake = 10000
eskrim = 15000
print("==========soal1==========")
burger1 = 6
pizza1 = 3
dimsum1 = 4
ekado1 = 4
milkshake1 = 2
es1 = 5
total = 25
js = (burger1 * burger) + (pizza1 * pizza) + (dimsum1 * dimsum) + (ekado1 * ekado) + (milkshake1 * milkshake) + (es1 * eskrim)
jm = (burger1 + pizza1 + dimsum1 + ekado1 + milkshake1 + es1) 
print("jadi total harga dari semua makanan adalah Rp : " + str(js))
print()
print("==========soal2==========")
f1 = burger1 / jm * 100
f2 = pizza1 / jm * 100
f3 = dimsum1 / jm * 100
f4 = ekado1 / jm * 100
f5 = milkshake1 / jm * 100
f6 = es1 / jm * 100
print("persentaseu burger : "+str(f1) +'%')
print("persentaseu pizza  :" +str(f2)+'%')
print("persentaseu dimsum :" +str(f3)+'%')
print("persentaseu ekado  :" +str(f4)+'%')
print("persentaseu milkshake : " +str(f5)+'%')
print("persentaseu eskrim :" +str(f6)+'%')
print()

# PIECART
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("Data Persentaseu Pembelian makanan")
jurusan = ['burger', 'pizza', 'dimsum', 'ekado', 'milkshake', 'eskrim']
siswa = [25.0, 12.5, 16.666666666666664, 16.666666666666664, 8.333333333333332, 20.833333333333336]
ax.pie(siswa,labels=jurusan,autopct='%1.2f%%')
plt.show()
print("==========soal3==========")
print("Ahmad")
burger = 4
pizza = 2
jarak = 7.5
uang_a = 200000
jml_a = (0.70 * ((burger * 24000) + (pizza * 52000))) + (7.5 * 2000) - 5000
hasil_a = uang_a - jml_a
print("maka total belanjaan ahmad adalah  :Rp. " +str(jml_a))
print("maka kembalian dan ahmad adalah    :Rp. " +str(hasil_a))

print("Beni")
dimsum = 3
eskrim = 1
milkshake = 2
uang_b = 150000
jml_b = (0.70 * ((dimsum * 30000) + (eskrim * 15000) + (milkshake * 10000))) + (4 * 1800) - 5000
hasil_b = uang_b - jml_b
print("maka total belanjaan beni adalah   :Rp. " +str(jml_b))
print("maka kembalian dan beni adalah     :Rp. " +str(hasil_b))

print("Citra")
eskrim = 3
uang_c = 60000
jml_c = (eskrim * 15000) + (8 * 2000) - 5000
hasil_c = uang_c - jml_c
print("maka total belanjaan citra adalah  :Rp. " +str(jml_c))
print("maka kembalian dan citra adalah    :Rp. " +str(hasil_c))

print("Dadang")
burger = 2
dimsum = 1
uang_d = 100000
jml_d = (0.80 * ((burger * 24000) + (dimsum * 30000))) + (5 * 1800) - 5000
hasil_d = uang_d - jml_d
print("maka total belanjaan dadang adalah :Rp. " +str(jml_d))
print("maka kembalian dan dadang adalah   :Rp. " +str(hasil_d))

print("Epen")
ekkado = 4
eskrim = 1
pizza = 1
uang_e = 100000
jml_e = (0.70 * ((ekkado * 7500) + (eskrim * 15000) + (pizza *  52000))) + (12 * 2200) - 5000
hasil_e = uang_e - jml_e
print("maka total belanjaan epen adalah   :Rp. " +str(jml_e))
print("maka kembalian dan epen adalah     :Rp. " +str(hasil_e))

print("==========soal4=========")
burger = 4
pizza = 2
jml_a = (0.30 * ((burger * 24000) + (pizza * 52000))) + 5000
print("maka jumlah potongan ahmad adalah  :Rp. " +str(jml_a))

dimsum = 3
eskrim = 1
jml_b = (0.30 * ((dimsum * 30000) + (eskrim * 15000) + (milkshake * 10000))) + 5000
print("maka jumlah potongan beni adalah   :Rp. " +str(jml_b))

eskrim = 3
uang_c = 60000
jml_c =(0.20 * ((eskrim * 15000))) - 4000
print("maka jumlah potongan citra adalah  :Rp. " +str(jml_c))

burger = 2
dimsum = 1
uang_d = 100000
jml_d = (0.30 * ((burger * 24000) + (dimsum * 30000))) - 5000
print("maka jumlah potongan dadang adalah :Rp. " +str(jml_d))

ekkado = 4
eskrim = 1
pizza = 1
uang_e = 100000
jml_e = (0.20 * ((ekkado * 7500) + (eskrim * 15000) + (pizza *  52000))) - 5000
print("maka jumlah potongan epen adalah   :Rp. " +str(jml_e))
print("==========soal5=========")
jarak = (7.5 * 2000) + (4 * 1800) + (8 * 2000) + (5 * 1800) + (12 * 2200)
print("maka jumlah potongan epen adalah   :Rp. " +str(jarak))
# Out:
# ==========soal1==========
# jadi total harga dari semua makanan adalah Rp : 545000
#
# ==========soal2==========
# persentaseu burger : 25.0%
# persentaseu pizza  :12.5%
# persentaseu dimsum :16.666666666666664%
# persentaseu ekado  :16.666666666666664%
# persentaseu milkshake : 8.333333333333332%
# persentaseu eskrim :20.833333333333336%
# ==========soal3==========
# Ahmad
# maka total belanjaan ahmad adalah  :Rp. 150000.0
# maka kembalian dan ahmad adalah    :Rp. 50000.0
# Beni
# maka total belanjaan beni adalah   :Rp. 89700.0
# maka kembalian dan beni adalah     :Rp. 60300.0
# Citra
# maka total belanjaan citra adalah  :Rp. 56000
# maka kembalian dan citra adalah    :Rp. 4000
# Dadang
# maka total belanjaan dadang adalah :Rp. 66400.0
# maka kembalian dan dadang adalah   :Rp. 33600.0
# Epen
# maka total belanjaan epen adalah   :Rp. 89300.0
# maka kembalian dan epen adalah     :Rp. 10700.0
# ==========soal4=========
# maka jumlah potongan ahmad adalah  :Rp. 65000.0
# ...
