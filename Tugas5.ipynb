# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
laba_1 = 32500000
laba_2 = 31000000
laba_3 = 42000000
laba_4 = 51500000
laba_5 = 27000000

utang_1 = 0.08
utang_2 = 0.04
utang_3 = 0.12
utang_4 = 0.11
utang_5 = 0.03

karyawan_a = 20
karyawan_b = 14
karyawan_c = 28
karyawan_d = 42
karyawan_e = 18

gaji_a = 300000
gaji_b = 360000
gaji_c = 475000
gaji_d = 580000
gaji_e = 400000
asuransi = 75000
print("==========SOAL1==========")
jml_a = ((karyawan_a * gaji_a)) + ((karyawan_a * asuransi))
jml_b = ((karyawan_b * gaji_b)) + ((karyawan_b * asuransi))
jml_c = ((karyawan_c * gaji_c)) + ((karyawan_c * asuransi))
jml_d = ((karyawan_d * gaji_d)) + ((karyawan_d * asuransi))
jml_e = ((karyawan_e * gaji_e)) + ((karyawan_e * asuransi))

print(" pengeluaran gaji + asuransi setiap perusahaan A-Xis    : Rp." +str(jml_a))
print(" pengeluaran gaji + asuransi setiap perusahaan B-Log    : Rp." +str(jml_b))
print(" pengeluaran gaji + asuransi setiap perusahaan C-in     : Rp." +str(jml_c))
print(" pengeluaran gaji + asuransi setiap perusahaan D-Namic  : Rp." +str(jml_d))
print(" pengeluaran gaji + asuransi setiap perusahaan E-Plison : Rp." +str(jml_e))
print()

print("==========SOAL2==========")
pajak = 0.03
pertahun = 12
jml_1 = ((laba_1 * pajak)) + ((utang_1 * 280000000))
jml_2 = ((laba_2 * pajak)) + ((utang_2 * 310000000))
jml_3 = ((laba_3 * pajak)) + ((utang_3 * 420000000))
jml_4 = ((laba_4 * pajak)) + ((utang_4 * 550000000))
jml_5 = ((laba_5 * pajak)) + ((utang_5 * 340000000))
print("maka total pajak dan utang a adalah : Rp." +str(jml_1))
print("maka total pajak dan utang b adalah : Rp." +str(jml_2))
print("maka total pajak dan utang c adalah : Rp." +str(jml_3))
print("maka total pajak dan utang d adalah : Rp." +str(jml_4))
print("maka total pajak dan utang e adalah : Rp." +str(jml_5))
#pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ['A-Xis', 'B-Log', 'C-In', 'D-Namic', 'E-Psilon']
total = [23375000.0, 13330000.0, 51660000.0, 62045000.0, 11010000.0]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black']
plt.title("Data Pengeluaran pajak dan gaji")
ax.pie(total,labels=perusahaan,autopct='%1.2f%%')
plt.show()
print()
#grafik BAR
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ['A-Xis', 'B-Log', 'C-In', 'D-Namic', 'E-Psilon']
total = [23375000.0, 13330000.0, 51660000.0, 62045000.0, 11010000.0]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black']
plt.title("Data Pengeluaran pajak dan gaji")
plt.bar(perusahaan, total, color = c)
plt.show()
print()

print("==========SOAL3==========")
asset_a = 280000000
asset_b = 310000000
asset_c = 420000000
asset_d = 550000000
asset_e = 340000000
csr = 0.025
csr2 = 0.035
hasil_1 = asset_a * csr
print("Maka CSR perusahaan a adalah : Rp."+str(hasil_1))
hasil_2 = asset_b * csr2
print("Maka CSR perusahaan b adalah : Rp."+str(hasil_2))
hasil_3 = asset_c * csr2
print("Maka CSR perusahaan c adalah : Rp."+str(hasil_3))
hasil_4 = asset_d * csr2
print("Maka CSR perusahaan d adalah : Rp."+str(hasil_4))
hasil_5 = asset_e * csr2
print("Maka CSR perusahaan e adalah : Rp."+str(hasil_5))
#grafik BAR
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ['A-Xis', 'B-Log', 'C-In', 'D-Namic', 'E-Psilon']
total = [700000000.0, 1085000000.0, 1470000000.0, 1925000000.0, 1190000000.0]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black']
plt.title("Data Pengeluaran pajak dan gaji")
plt.bar(perusahaan, total, color = c)
plt.show()
print()
#pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ['A-Xis', 'B-Log', 'C-In', 'D-Namic', 'E-Psilon']
total = [700000000.0, 1085000000.0, 1470000000.0, 1925000000.0, 1190000000.0]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black']
plt.title("Data Pengeluaran pajak dan gaji")
ax.pie(total,labels=perusahaan,autopct='%1.2f%%')
plt.show()
print()
print("==========SOAL4==========")
hasil1 = laba_1 * 12
hasil2 = laba_2 * 12
hasil3 = laba_3 * 12
hasil4 = laba_4 * 12
hasil5 = laba_5 * 12
hasil_6 = hasil1 + hasil2 + hasil3 + hasil4 + hasil5 
print("total laba semua perusahaan selama 1 tahun adalah : Rp."+str(hasil_6))
print()
print("==========SOAL5==========")
hasil_a = (laba_1 * 12) - csr * 280000000 - (7500000 * 12) - 23375000.0
hasil_b = (laba_2 * 12) - csr2 * 310000000 - (6090000 * 12) - 13330000.0
hasil_c = (laba_3 * 12) - csr2 * 420000000 - (15400000 * 12) - 51660000.0
hasil_d = (laba_4 * 12) - csr2 * 550000000 - (27510000 * 12) - 62045000.0
hasil_e = (laba_5 * 12) - csr2 * 340000000 - (8550000 * 12) - 11010000.0
print("total pendapatan bersih pertahun perusahaan a : Rp." +str(hasil_a))
print("total pendapatan bersih pertahun perusahaan b : Rp." +str(hasil_b))
print("total pendapatan bersih pertahun perusahaan c : Rp." +str(hasil_c))
print("total pendapatan bersih pertahun perusahaan d : Rp." +str(hasil_d))
print("total pendapatan bersih pertahun perusahaan e : Rp." +str(hasil_e))
#grafik BAR
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
perusahaan = ['A-Xis', 'B-Log', 'C-In', 'D-Namic', 'E-Psilon']
total = [269625000.0, 274740000.0, 252840000.0, 206585000.0, 198490000.0]
c = ['red', 'green', 'blue', 'yellow', 'orange']
plt.title("Data Pendapatan Pertahun")
plt.bar(perusahaan, total, color = c)
plt.show()
print()
#pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
perusahaan = ['A-Xis', 'B-Log', 'C-In', 'D-Namic', 'E-Psilon']
total = [269625000.0, 274740000.0, 252840000.0, 206585000.0, 198490000.0]
c = ['red', 'green', 'blue', 'yellow', 'orange']
plt.title("Data Pendapatan Pertahun")
ax.pie(total,labels=perusahaan,autopct='%1.2f%%')
plt.show()
# Out:
# ==========SOAL1==========
#  pengeluaran gaji + asuransi setiap perusahaan A-Xis    : Rp.7500000
#  pengeluaran gaji + asuransi setiap perusahaan B-Log    : Rp.6090000
#  pengeluaran gaji + asuransi setiap perusahaan C-in     : Rp.15400000
#  pengeluaran gaji + asuransi setiap perusahaan D-Namic  : Rp.27510000
#  pengeluaran gaji + asuransi setiap perusahaan E-Plison : Rp.8550000
#
# ==========SOAL2==========
# maka total pajak dan utang a adalah : Rp.23375000.0
# maka total pajak dan utang b adalah : Rp.13330000.0
# maka total pajak dan utang c adalah : Rp.51660000.0
# maka total pajak dan utang d adalah : Rp.62045000.0
# maka total pajak dan utang e adalah : Rp.11010000.0
# ==========SOAL3==========
# Maka CSR perusahaan a adalah : Rp.7000000.0
# Maka CSR perusahaan b adalah : Rp.10850000.000000002
# Maka CSR perusahaan c adalah : Rp.14700000.000000002
# Maka CSR perusahaan d adalah : Rp.19250000.0
# Maka CSR perusahaan e adalah : Rp.11900000.000000002
# ==========SOAL4==========
# ...
