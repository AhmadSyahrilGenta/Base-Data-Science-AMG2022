# %%
import matplotlib.pyplot as plt
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
#grafik Batang
print("==========SOAL1==========")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pen = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'Volly', 'Kesenian', 'Rohis']
jmlh = [5, 18, 30, 7, 16, 19, 12 ]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black', 'purple']
plt.title("Jumlah Siswa Yang Mengikuti Eskul Di Kelas 10")
plt.bar(pen, jmlh, color = c)
plt.show()
print()

print("==========SOAL2==========")
a = 5
b = 21
c = 6
hasil_a = a + b + c
print("Jumlah siswa yang mengikuti eskul Paskibra: " + str(hasil_a))

a = 18
b = 4
c = 12
hasil_b = a + b + c
print("Jumlah siswa yang mengikuti eskul PMR: " + str(hasil_b))

a = 30
b = 8
c = 24
hasil_c = a + b + c
print("Jumlah siswa yang mengikuti eskul Pramuka: " + str(hasil_c))

a = 7
b = 29
c = 15
hasil_d = a + b + c
print("Jumlah siswa yang mengikuti eskul Futsal: " + str(hasil_d))

a = 16
b = 10
c = 12
hasil_e = a + b + c
print("Jumlah siswa yang mengikuti eskul Volly: " + str(hasil_e))

a = 19 
b = 18
c = 4
hasil_f = a + b + c
print("Jumlah siswa yang mengikuti eskul Kesenian: " + str(hasil_f))

a = 12
b = 10
c = 7
hasil_g = a + b + c
print("Jumlah siswa yang mengikuti eskul Rohis: " + str(hasil_g))

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pen = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'Volly', 'Kesenian', 'Rohis']
jmlh = [32, 34, 62, 51, 38, 41, 29 ]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black', 'purple']
plt.title("ESKUL")
plt.bar(pen, jmlh, color = c)
plt.show()     
print()

print("==========SOAL3=========")
a = 7
b = 29
c = 15
d = 16
e = 10
f = 12
m = 287
td = 45

hasil = (a + b + c + d + e + f)
hasil2 = (m - hasil)
print("jumlah yang mengikuti olahraga: " + str(hasil2))
print("jumlah yang mengikuti: " + str(hasil))
print("jumlah yang tidak mengikuti: " + str(td))
hasil3 = (hasil2 / 332) * 10
hasil4 = (td / 332) * 10
hasil5 = (hasil / 332) * 10
print(hasil3)
print(hasil4)
print(hasil5)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
eskul = ['OLAHRAGA', 'MENGIKUTI', 'TIDAK MENGIKUTI']
mengikuti = [198, 89, 45]
c = ['orange', 'black', 'purple']
plt.title("ESKUL")
plt.bar(eskul, mengikuti, color = c)
plt.show()
print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
eskul = ['OLAHRAGA', 'MENGIKUTI', 'TIDAK MENGIKUTI']
mengikuti = [198, 89, 45]
c = ['orange', 'black', 'purple']
plt.title("ESKUL")
ax.pie(mengikuti,labels=eskul,autopct='%1.2f%%')
plt.show()
print()

print("==========SOAL4==========")
td = 17
td1 = 8
td2 = 20
jml_td1 = td + td1 + td2 
print("yang tidak mengikuti eskul : " + str(jml_td1))
indeks = 45
b_indeks = (td / indeks ) * 100
print("persentaseu siswa tidak mengikuti kelas 10 : " + str(b_indeks))
indeks = 45
b_indeks2 = (td2 / indeks ) * 100
print("persentaseu siswa tidak mengikuti kelas 11 : " + str(b_indeks2))
indeks = 45
b_indeks3 = (td2 / indeks ) * 100
print("persentaseu siswa tidak mengikuti kelas 12 : " + str(b_indeks3))
jml_pers=b_indeks+b_indeks2+b_indeks3
print("Maka hasil persentarinya adalah : " + str(jml_pers))
presentaseu = [32.7, 17.7, 44.4]
print("maka presentaseu nya adalah :" + str(presentaseu))

print()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
pen = ['']
jmlh = [6, 12, 24, 15, 12, 4, 7 ]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black', 'purple']
plt.title("kelas 12")
ax.pie(jmlh,labels=pen,autopct='%1.2f%%')
plt.show()


print()
print("==========SOAL5==========")
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pen = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'Volly', 'Kesenian', 'Rohis']
jmlh = [5, 18, 30, 7, 16, 19, 12 ]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black', 'purple']
plt.title("kelas 10")
plt.bar(pen, jmlh, color = c)
plt.show()
print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
pen = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'Volly', 'Kesenian', 'Rohis']
jmlh = [5, 18, 30, 7, 16, 19, 12 ]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black', 'purple']
plt.title("kelas 10")
ax.pie(jmlh,labels=pen,autopct='%1.2f%%')
plt.show()
print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pen = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'Volly', 'Kesenian', 'Rohis']
jmlh = [21, 4, 8, 29, 10, 18, 10 ]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black', 'purple']
plt.title("kelas 11")
plt.bar(pen, jmlh, color = c)
plt.show()
print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
pen = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'Volly', 'Kesenian', 'Rohis']
jmlh = [21, 4, 8, 29, 10, 18, 10 ]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black', 'purple']
plt.title("kelas 11")
ax.pie(jmlh,labels=pen,autopct='%1.2f%%')
plt.show()
print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pen = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'Volly', 'Kesenian', 'Rohis']
jmlh = [6, 12, 24, 15, 12, 4, 7 ]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black', 'purple']
plt.title("kelas 12")
plt.bar(pen, jmlh, color = c)
plt.show()
print()

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
pen = ['Paskibra', 'PMR', 'Pramuka', 'Futsal', 'Volly', 'Kesenian', 'Rohis']
jmlh = [6, 12, 24, 15, 12, 4, 7 ]
c = ['red', 'green', 'blue', 'yellow', 'orange', 'black', 'purple']
plt.title("kelas 12")
ax.pie(jmlh,labels=pen,autopct='%1.2f%%')
plt.show()
# Out:
# ==========SOAL1==========
# ==========SOAL2==========
# Jumlah siswa yang mengikuti eskul Paskibra: 32
# Jumlah siswa yang mengikuti eskul PMR: 34
# Jumlah siswa yang mengikuti eskul Pramuka: 62
# Jumlah siswa yang mengikuti eskul Futsal: 51
# Jumlah siswa yang mengikuti eskul Volly: 38
# Jumlah siswa yang mengikuti eskul Kesenian: 41
# Jumlah siswa yang mengikuti eskul Rohis: 29
# ==========SOAL3=========
# jumlah yang mengikuti olahraga: 198
# jumlah yang mengikuti: 89
# jumlah yang tidak mengikuti: 45
# 5.9638554216867465
# 1.355421686746988
# 2.680722891566265
# ==========SOAL4==========
# yang tidak mengikuti eskul : 45
# persentaseu siswa tidak mengikuti kelas 10 : 37.77777777777778
# persentaseu siswa tidak mengikuti kelas 11 : 44.44444444444444
# persentaseu siswa tidak mengikuti kelas 12 : 44.44444444444444
# Maka hasil persentarinya adalah : 126.66666666666667
# maka presentaseu nya adalah :[32.7, 17.7, 44.4]
#
# ==========SOAL5==========
